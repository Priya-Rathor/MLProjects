# %% [markdown]
# # 1.Introduction to Plotly
#
# 1. Until now we did visualisations using Matplotlib, seaborn and Pandas . All if them Produce static image files.
#
# 2. Plotly is company based out in Canada famous for it's products like plotly and Dash
#
# 3. plotly create interactive visualisations in the form of HTML files
#
# 4. Drawback can't work a ive data source
#
# 5. Dash  is used to create live data based dashboards.

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (6.0.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from plotly) (1.15.1)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from plotly) (24.2)

# %%
import numpy as np
import pandas as pd 
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
match = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

ipl = delivery.merge(match,left_on='match_id',right_on= 'id')
ipl.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  toss_decision  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...          field
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...          field
#
#                   winner result  result_margin target_runs target_overs  \
# 0  Kolkata Knight Riders   runs          140.0       223.0         20.0
# 1  Kolkata Knight Riders   runs          140.0       223.0         20.0
# 2  Kolkata Knight Riders   runs          140.0       223.0         20.0
# 3  Kolkata Knight Riders   runs          140.0       223.0         20.0
# 4  Kolkata Knight Riders   runs          140.0       223.0         20.0
#
#   super_over  method    umpire1      umpire2
# 0          N     NaN  Asad Rauf  RE Koertzen
# 1          N     NaN  Asad Rauf  RE Koertzen
# 2          N     NaN  Asad Rauf  RE Koertzen
# 3          N     NaN  Asad Rauf  RE Koertzen
# 4          N     NaN  Asad Rauf  RE Koertzen
#
# [5 rows x 37 columns]

# %% [markdown]
# # 1. Scatter Plots
#
#  1.Scatter plots are drown bwtween to continous variables
#
#  Problem :- We are going to draw a scatter plot between batsman avg(x axis) and
#
#  Batsman strike Rate (Y axis) of thje top 50 batsman in IPL (all time)

# %%
print(ipl.columns)
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date',
#        'match_type', 'player_of_match', 'venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'target_runs', 'target_overs', 'super_over', 'method', 'umpire1',
#        'umpire2'],
#       dtype='object')

# %%
top50 = ipl.groupby('batter')['batsman_runs'].sum().sort_values(ascending=False).head(50).index.tolist()
new_ipl = ipl[ipl['batter'].isin(top50)]

# %%
# Calculating SR
# SR = [(number of runs scored)/(number of balls played)] * 100

runs = new_ipl.groupby('batter')['batsman_runs'].sum()
balls = new_ipl.groupby('batter')['batsman_runs'].count()

sr = (runs/balls)*100

sr =sr.reset_index()
sr
# Out:
#             batter  batsman_runs
# 0   AB de Villiers    148.580442
# 1       AD Russell    164.224422
# 2         AJ Finch    123.349057
# 3        AM Rahane    120.321410
# 4        AT Rayudu    124.584527
# 5      BB McCullum    126.848592
# 6         CH Gayle    142.121729
# 7        DA Miller    134.684477
# 8        DA Warner    135.429986
# 9         DR Smith    132.279534
# 10    F du Plessis    133.071325
# 11       G Gambhir    119.665153
# 12      GJ Maxwell    150.488599
# 13       HH Pandya    139.691290
# 14    Ishan Kishan    132.797589
# 15      JC Buttler    142.238984
# 16       JH Kallis    105.936272
# 17      KA Pollard    140.457703
# 18      KD Karthik    131.353404
# 19        KL Rahul    131.050866
# 20   KS Williamson    122.952710
# 21         M Vijay    118.614130
# 22      MA Agarwal    128.255646
# 23       MK Pandey    117.366180
# 24        MS Dhoni    132.835065
# 25          N Rana    130.818859
# 26        PA Patel    116.625717
# 27       Q de Kock    131.120332
# 28        R Dravid    113.347237
# 29       RA Jadeja    124.432296
# 30     RA Tripathi    135.515152
# 31      RD Gaikwad    133.632791
# 32       RG Sharma    127.918194
# 33         RR Pant    143.597561
# 34      RV Uthappa    126.152279
# 35        S Dhawan    123.454313
# 36        SA Yadav    142.505948
# 37        SE Marsh    130.109775
# 38        SK Raina    132.535312
# 39       SPD Smith    124.812406
# 40    SR Tendulkar    114.187867
# 41       SR Watson    134.163209
# 42         SS Iyer    123.025540
# 43       SV Samson    135.137615
# 44    Shubman Gill    132.236842
# 45         V Kohli    128.511867
# 46        V Sehwag    148.827059
# 47         WP Saha    123.902027
# 48       YK Pathan    138.046272
# 49    Yuvraj Singh    124.784776

# %%
# Calculating Avg
# Avg = (Total number of Runs)/(number of outs)
# calculating number of outs of for tiop 50 batsman

out = ipl[ipl['player_dismissed'].isin(top50)]
nouts = out['player_dismissed'].value_counts()

avg = runs/nouts

avg = avg.reset_index()

avg.rename(columns={'index':'batter',0:'avg'}, inplace=True)

avg = avg.merge(sr,on='batter')

# %%
# Plot Scatter Plot here
trace = go.Scatter(x=avg['avg'],y=avg['batsman_runs'],mode='markers',text=avg['batter'] , marker={'color':"#00a65a",'size':16})
data = [trace]

layout = go.Layout(title='batsman Avg vs SR', xaxis = {'title':'Batsman Average'},yaxis={'title':'Batsman Strike rate' })
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # 2.Line Chart
#
# It's an extension of Scatter plot. Usually . used to  show a time series data

# %%
# Year by year batsman performance

single = ipl[ipl['batter'] == 'V Kohli']
performance = single.groupby('season')['batsman_runs'].sum().reset_index()
performance

single1 = ipl[ipl['batter'] == 'MS Dhoni']
performance1 = single1.groupby('season')['batsman_runs'].sum().reset_index()
performance1
# Out:
#      season  batsman_runs
# 0   2007/08           414
# 1      2009           332
# 2   2009/10           287
# 3      2011           392
# 4      2012           358
# 5      2013           461
# 6      2014           371
# 7      2015           372
# 8      2016           284
# 9      2017           290
# 10     2018           455
# 11     2019           416
# 12  2020/21           200
# 13     2021           114
# 14     2022           232
# 15     2023           104
# 16     2024           161

# %%
# Plot Line chart here 
trace = go.Scatter(
    x=performance['season'],
    y=performance['batsman_runs'],
    mode='lines',  # Corrected from 'node' to 'mode'
    marker=dict(color='#00a65a')  # Corrected marker syntax
)


trace1 = go.Scatter(
    x=performance1['season'],
    y=performance1['batsman_runs'],
    mode='lines',  # Corrected from 'node' to 'mode'
)

data = [trace,trace1]

layout = go.Layout(title='Year by Year Performance',xaxis={'title':'Season'},yaxis={'title':'Total runs'})

fig = go.Figure(data=data,layout=layout)

pyo.plot(fig, filename='myfile.html')
# Out:
# 'myfile.html'

# %%
# Multiple Line Charts

def batsman_comp(*name):
    data = []
    for i in name:
        single = ipl[ipl['batter']==i]
        performance=single.groupby('season')['batsman_runs'].sum().reset_index()

        trace = go.Scatter(x=performance['season'],y=performance['batsman_runs'],mode='lines + markers',name=i)

        data.append(trace)

    layout = go.Layout(title='Batsman Record comparator',xaxis={'title':'Season'},yaxis={'title':'Runs'})

    fig = go.Figure(data=data, layout=layout)

    pyo.plot(fig, filename='Year_by_year.html')

# %%
batsman_comp('V Kohli','RG Sharma','DA Warner','MS Dhni')

# %% [markdown]
# # 3 Bar Plot

# %%
top10 = ipl.groupby('batter')['batsman_runs'].sum().sort_values(ascending=False).head(10).index.tolist()
top10_df = ipl[ipl['batter'].isin(top10)]

# %%
top10_score = top10_df.groupby('batter')['batsman_runs'].sum().reset_index()
top10_score
# Out:
#            batter  batsman_runs
# 0  AB de Villiers          5181
# 1        CH Gayle          4997
# 2       DA Warner          6567
# 3      KD Karthik          4843
# 4        MS Dhoni          5243
# 5       RG Sharma          6630
# 6      RV Uthappa          4954
# 7        S Dhawan          6769
# 8        SK Raina          5536
# 9         V Kohli          8014

# %%
# plot bar Graph

trace=go.Bar(x=top10_score['batter'], y=top10_score['batsman_runs'])

data = [trace]
layout=go.Layout(title='Top 10 IPL batsman',
                 xaxis={'title':'Batter'},
                 yaxis={'title':'Total Runs'})

fig= go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # There are two type of Bar Graphs
# 1. Nested Bar Graph
#
# 2.stacked Bar Graph
#
# 3. Overlayed Bar Graph

# %%
iw = top10_df.groupby(['batter','inning'])['batsman_runs'].sum().reset_index()
mask = iw['inning'] == 1
mask2=iw['inning'] == 2
one = iw[mask]
two = iw[mask2]

one.rename(columns={'batsman_runs':'1st Innings'},inplace=True)
two.rename(columns={'batsman_runs':'2nd Innings'},inplace =True)

final = one.merge(two, on='batter')[['batter','1st Innings','2nd Innings']]

final
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21660\2831680550.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_21660\2831680550.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            batter  1st Innings  2nd Innings
# 0  AB de Villiers         3163         1999
# 1        CH Gayle         2873         2092
# 2       DA Warner         3280         3285
# 3      KD Karthik         2743         2099
# 4        MS Dhoni         3065         2178
# 5       RG Sharma         3600         3028
# 6      RV Uthappa         2120         2832
# 7        S Dhawan         3926         2843
# 8        SK Raina         3194         2334
# 9         V Kohli         4400         3604

# %%
trace1 = go.Bar(x= final['batter'],y=final['1st Innings'],name='1st innings',marker={'color':'#00a65a'})

trace2 = go.Bar(x=final['batter'],y=final['2nd Innings'],name='2nd inninga',marker={'color':'#a6a65a'})

data = [trace1,trace2]

layout = go.Layout(title='Inning wise scores',
                   xaxis={'title':'batter'},
                   yaxis={'title':'Runs'},
                   barmode='overlay')

# barmode = 'stack'
# barmode = not any things

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Bubble plot
#
# Again an extension of Scatter plot with some additional informations

# %%
avg
# Out:
#             batter        avg  batsman_runs
# 0   AB de Villiers  39.853846    148.580442
# 1       AD Russell  28.930233    164.224422
# 2         AJ Finch  24.904762    123.349057
# 3        AM Rahane  30.142857    120.321410
# 4        AT Rayudu  28.051613    124.584527
# 5      BB McCullum  27.711538    126.848592
# 6         CH Gayle  39.658730    142.121729
# 7        DA Miller  35.658537    134.684477
# 8        DA Warner  40.042683    135.429986
# 9         DR Smith  28.392857    132.279534
# 10    F du Plessis  35.992126    133.071325
# 11       G Gambhir  31.007353    119.665153
# 12      GJ Maxwell  24.750000    150.488599
# 13       HH Pandya  28.471910    139.691290
# 14    Ishan Kishan  28.430108    132.797589
# 15      JC Buttler  37.715789    142.238984
# 16       JH Kallis  28.552941    105.936272
# 17      KA Pollard  28.404959    140.457703
# 18      KD Karthik  26.320652    131.353404
# 19        KL Rahul  44.657143    131.050866
# 20   KS Williamson  35.533333    122.952710
# 21         M Vijay  25.930693    118.614130
# 22      MA Agarwal  22.811966    128.255646
# 23       MK Pandey  29.015038    117.366180
# 24        MS Dhoni  39.126866    132.835065
# 25          N Rana  28.344086    130.818859
# 26        PA Patel  22.603175    116.625717
# 27       Q de Kock  30.980392    131.120332
# 28        R Dravid  28.233766    113.347237
# 29       RA Jadeja  27.398148    124.432296
# 30     RA Tripathi  26.939759    135.515152
# 31      RD Gaikwad  41.754386    133.632791
# 32       RG Sharma  29.730942    127.918194
# 33         RR Pant  35.451613    143.597561
# 34      RV Uthappa  27.522222    126.152279
# 35        S Dhawan  35.072539    123.454313
# 36        SA Yadav  31.805310    142.505948
# 37        SE Marsh  39.507937    130.109775
# 38        SK Raina  32.374269    132.535312
# 39       SPD Smith  34.652778    124.812406
# 40    SR Tendulkar  33.826087    114.187867
# 41       SR Watson  30.793651    134.163209
# 42         SS Iyer  31.948980    123.025540
# 43       SV Samson  30.687500    135.137615
# 44    Shubman Gill  37.835294    132.236842
# 45         V Kohli  38.714976    128.511867
# 46        V Sehwag  27.555556    148.827059
# 47         WP Saha  24.247934    123.902027
# 48       YK Pathan  29.290909    138.046272
# 49    Yuvraj Singh  24.810811    124.784776

# %%
new_ipl = new_ipl[new_ipl['batsman_runs']==6]

# %%
six = new_ipl.groupby('batter')['batsman_runs'].count().reset_index()
x = avg.merge(six,on = 'batter')
x

trace = go.Scatter(x=x['avg'],y=x['batsman_runs_x'],mode='marker',marker={'size':x['batsman_runs_y']},name=x['batter'])

data = [trace]

layout= go.Layout(title='Bubble Chart',
                  xaxis={'title':'Avrage'},
                  yaxis={'title':'SR'})

fig = go.Figure(data= data,layout=layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 5
#       2 x = avg.merge(six,on = 'batter')
#       3 x
# ----> 5 trace = go.Scatter(x=x['avg'],y=x['batsman_runs_x'],mode='marker',marker={'size':x['batsman_runs_y']},name=x['batter'])
#       7 data = [trace]
#       9 layout= go.Layout(title='Bubble Chart',
#      10                   xaxis={'title':'Avrage'},
#      11                   yaxis={'title':'SR'})
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\graph_objs\_scatter.py:3546, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    3544 _v = mode if mode is not None else _v
#    3545 if _v is not None:
# -> 3546     self["mode"] = _v
#    3547 _v = arg.pop("name", None)
#    3548 _v = name if name is not None else _v
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:4860, in BasePlotlyType.__setitem__(self, prop, value)
#    4856         self._set_array_prop(prop, value)
#    4858     # ### Handle simple property ###
#    4859     else:
# -> 4860         self._set_prop(prop, value)
#    4861 else:
#    4862     # Make sure properties dict is initialized
#    4863     self._init_props()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5204, in BasePlotlyType._set_prop(self, prop, val)
#    5202         return
#    5203     else:
# -> 5204         raise err
#    5206 # val is None
#    5207 # -----------
#    5208 if val is None:
#    5209     # Check if we should send null update
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5199, in BasePlotlyType._set_prop(self, prop, val)
#    5196 validator = self._get_validator(prop)
#    5198 try:
# -> 5199     val = validator.validate_coerce(val)
#    5200 except ValueError as err:
#    5201     if self._skip_invalid:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:1929, in FlaglistValidator.validate_coerce(self, v)
#    1927     validated_v = self.vc_scalar(v)
#    1928     if validated_v is None:
# -> 1929         self.raise_invalid_val(v)
#    1931     v = validated_v
#    1933 return v
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:299, in BaseValidator.raise_invalid_val(self, v, inds)
#     296             for i in inds:
#     297                 name += "[" + str(i) + "]"
# --> 299         raise ValueError(
#     300             """
#     301     Invalid value of type {typ} received for the '{name}' property of {pname}
#     302         Received value: {v}
#     303
#     304 {valid_clr_desc}""".format(
#     305                 name=name,
#     306                 pname=self.parent_name,
#     307                 typ=type_str(v),
#     308                 v=repr(v),
#     309                 valid_clr_desc=self.description(),
#     310             )
#     311         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'mode' property of scatter
#         Received value: 'marker'
#
#     The 'mode' property is a flaglist and may be specified
#     as a string containing:
#       - Any combination of ['lines', 'markers', 'text'] joined with '+' characters
#         (e.g. 'lines+markers')
#         OR exactly one of ['none'] (e.g. 'none')

# %%
trace = go.Scatter(x=x['avg'],y=x['batsman_runs_x'],mode='markers',marker={'size':x['batsman_runs_y']})

data = [trace]

layout= go.Layout(title='Bubble Chart',
                  xaxis={'title':'Avrage'},
                  yaxis={'title':'SR'})

fig = go.Figure(data= data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Box Plot
#
# A box and whisker plot -- also called a box plot --displays the five -number summary of a set of data.

# %%
match_agg = delivery.groupby(['match_id'])['total_runs'].sum().reset_index()
season_wise = match_agg.merge(match, left_on='match_id',right_on='id')[['match_id','total_runs','season']]
season_wise
# Out:
#       match_id  total_runs   season
# 0       335982         304  2007/08
# 1       335983         447  2007/08
# 2       335984         261  2007/08
# 3       335985         331  2007/08
# 4       335986         222  2007/08
# ...        ...         ...      ...
# 1090   1426307         429     2024
# 1091   1426309         323     2024
# 1092   1426310         346     2024
# 1093   1426311         314     2024
# 1094   1426312         227     2024
#
# [1095 rows x 3 columns]

# %%
trace= go.Box(x=season_wise['total_runs'],name='All seasons')

data=[trace]

layout=go.Layout(title='Total core analysis',
                 xaxis={'title':'Total Score'})

fig = go.Figure(data=data,layout=layout)

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace1 = go.Box(x=season_wise[season_wise['season']==2017]['total_runs'],name="2017",marker={'color':'#00a65a'})
trace2 = go.Box(x=season_wise[season_wise['season']==2008]['total_runs'],name="2008")

data=[trace1,trace2]

layout=go.Layout(title='Total score analysis',
                 xaxis={'title':'Total Score'})

fig = go.Figure(data=data,layout=layout)

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# 7. Distplots

# %%
import plotly.figure_factory as ff

hist_data = [avg['avg'],avg['batsman_runs']]

group_labels =['Average','Srike Rate']

fig = ff.create_distplot(hist_data,group_labels,bin_size=[10,10])

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Histograms
#
# A histogram is a plot that lets you discover, and show the underlying frequency distribution(shape) of a set continuous data

# %%
x = delivery.groupby('batter')['batsman_runs'].count()>150
x=x[x].index.tolist()

new =delivery[delivery['batter'].isin(x)]

runs = new.groupby('batter')['batsman_runs'].sum()

balls = new.groupby('batter')['batsman_runs'].count()

sr = (runs/balls)*100
sr = sr.reset_index()

sr
# Out:
#               batter  batsman_runs
# 0     A Ashish Reddy    142.857143
# 1           A Badoni    125.544554
# 2          A Manohar    127.624309
# 3           A Mishra     86.590909
# 4          A Symonds    124.711908
# ..               ...           ...
# 235  Y Venugopal Rao    113.872832
# 236      YBK Jaiswal    146.757991
# 237        YK Pathan    138.046272
# 238      YV Takawale    104.918033
# 239     Yuvraj Singh    124.784776
#
# [240 rows x 2 columns]

# %%
trace = go.Histogram(x=sr['batsman_runs'])

data = [trace]

layout = go.Layout(title='Strike rate analysis',
                   xaxis={'title':'strike rates'})

fig= go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Heatmaps
#
# A heat map is agraphical representation of data where the individual values contained in a matrix are represented as colors

# %%
six = delivery[delivery['batsman_runs']==6]

six = six.groupby(['batting_team','over'])['batsman_runs'].count().reset_index()

six
# Out:
#             batting_team  over  batsman_runs
# 0    Chennai Super Kings     0             9
# 1    Chennai Super Kings     1            36
# 2    Chennai Super Kings     2            67
# 3    Chennai Super Kings     3            71
# 4    Chennai Super Kings     4            75
# ..                   ...   ...           ...
# 371  Sunrisers Hyderabad    15            56
# 372  Sunrisers Hyderabad    16            59
# 373  Sunrisers Hyderabad    17            73
# 374  Sunrisers Hyderabad    18            94
# 375  Sunrisers Hyderabad    19            79
#
# [376 rows x 3 columns]

# %%
trace= go.Heatmap(x=six['batting_team'],y=six['over'],z=six['batsman_runs'])

data = [trace]
layout= go.Layout(title='six Heatmap')

fig = go.Figure(data=data,layout=layout)

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
dots = delivery[delivery['batsman_runs']==0]
dots= dots.groupby(['batting_team','over'])['batsman_runs'].count().reset_index()

from plotly import tools
trace1 = go.Heatmap(x=six['batting_team'], y=six['over'],z=six['batsman_runs'].values.tolist())

trace2 = go.Heatmap(x=dots['batting_team'],y=dots['over'],
                    z=dots['batsman_runs'].values.tolist())

fig = tools.make_subplots(rows = 1,cols=2,subplot_titles=["6's","0's"],shared_yaxes=True)

fig.append_trace(trace1,1,1)
fig.append_trace(trace2,1,2)

pyo.plot(fig)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\tools.py:455: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# 'temp-plot.html'
